# %%
import pandas as pd             # pandas librayis used for data manipulation and analysis in python
import numpy as np              # numpy library is used for working with arrays in python
import matplotlib.pyplot as plt # maptlotlib is a library used for creating Static, animated interective visulaization in python
import seaborn as sns           # seaborn is a library for  making statistical graphics in python

# %%
df = pd.read_csv('SampleSuperstore.csv')  # read_csv file is used for import a CSV file to DataFrame foramt.

# %%
df       # this will shows the  two dimension data structure means rows and columns
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.info()   # The info function is used to print a concise summary of Dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# ##### The isnull() method returns a DataFrame object where all the values are replaced with a Boolean value True for NULL values, and otherwise False.

# %%
df.isnull().sum( )      # return number  of missing values in data set
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.shape               # this will return  total no of rows and columns in data  set
# Out:
# (9994, 13)

# %%
df.nunique()            # this will return no of  unique values in each column
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# #### Exploratory Data Analysis

# %% [markdown]
# Kernel Density Estimation (KDE) is a way to estimate the probability density function of a continuous random variable

# %% [markdown]
# The 'xlim()' function in pyplot module of matplotlib library is used to get or set the x-limits of the current axes

# %% [markdown]
# The show() function in pyplot module of matplotlib library is used to display all figures.

# %%
sns.kdeplot(df['Sales'],color='brown',label='Sales',shade=True)
sns.kdeplot(df['Profit'],color='green' ,label='Profit',shade=True)
plt.xlim([-100,1000])
plt.show()

# %% [markdown]
# #### Pairplot analysis of each column

# %% [markdown]
# ##### Dataframe is called df we just type print(df. columns) to get all the columns of the Pandas dataframe

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
# pairpolot based on category 
sns.pairplot(df,hue='Category')  # hue is a Variable in “data“ to map plot aspects to different colors.

# %%
# Base on Region
sns.pairplot(df,hue='Region')

# %%
sns.pairplot(df,hue='Segment')

# %%
df.describe()   # The describe() method returns description of the data in the DataFrame
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df1 =df.corr()   # .corr function is used to find pairwise correlation ofall columns in dataframe

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df1, annot=True)
plt.show()

# %% [markdown]
# #### Count plot of each columns

# %%
fig,axs= plt.subplots(nrows=2,ncols=2,figsize=(10,10))
sns.countplot(df['Category'],ax=axs[0][0])
sns.countplot(df['Segment'],ax=axs[0][1])
sns.countplot(df['Region'],ax=axs[1][0])
sns.countplot(df['Ship Mode'],ax=axs[1][1])
axs[0][0].set_title('Category')
axs[0][1].set_title('Segment')
axs[1][0].set_title('Region')
axs[1][1].set_title('Ship Mode')
# Out:
# C:\Users\IKRAM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\IKRAM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\IKRAM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(20,10))
sns.countplot(df['Sub-Category'])
plt.title('sub-Category',fontsize=10)
# Out:
# C:\Users\IKRAM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'sub-Category')

# %%
plt.figure(figsize=(20,20))
sns.countplot(df['State'])
plt.xticks(rotation=90)
plt.title('state',fontsize=20)
# Out:
# C:\Users\IKRAM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'state')

# %%
plt.figure(figsize=(20,10))
sns.countplot(df['Quantity'])
plt.title('quantity',fontsize=20)
# Out:
# C:\Users\IKRAM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'quantity')

# %%
plt.figure(figsize=(15,6))
sns.countplot(df['Discount'])
plt.title('Discount',fontsize=20)
# Out:
# C:\Users\IKRAM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Discount')

# %% [markdown]
# #### Distribution Plot

# %%
fig,axs = plt.subplots(ncols=2,nrows=2,figsize=(10,10))
sns.displot(df['Sales'],color='green', ax=axs[0][0])
sns.displot(df['Profit'],color='red', ax=axs[0][1])
sns.displot(df['Quantity'],color='yellow' ,ax=axs[1][0])
sns.displot(df['Discount'],color='brown',ax=axs[1][1])
axs[0][0].set_title('Sales Distribution' ,fontsize=20)
axs[0][1].set_title('Profit Distribution' ,fontsize=20)
axs[1][0].set_title('Quantity Distribution' ,fontsize=20)
axs[1][1].set_title('Discount Distribution' ,fontsize=20)
plt.show()
# Out:
# C:\Users\IKRAM\anaconda3\lib\site-packages\seaborn\distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\IKRAM\anaconda3\lib\site-packages\seaborn\distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\IKRAM\anaconda3\lib\site-packages\seaborn\distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\IKRAM\anaconda3\lib\site-packages\seaborn\distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Deal Analysis State wise

# %%
df1=df['Country'].value_counts()
df1
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
df1=df['State'].value_counts( )
df1
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
df1.plot(kind='bar',figsize=(20,10))
plt.ylabel('Frequency / Number of deals')
plt.xlabel('States')

plt.title('State Wise Dealings',fontsize=20)
plt.show()

# %% [markdown]
# #### Three State with Heigst Sales
# 1. Califronina
# 2. New York
# 3. Texas
#
# Woyming : lowest no of deals

# %% [markdown]
# #### Find  Average no deals pr state

# %%
df['State'].value_counts().mean()
# Out:
# 203.9591836734694

# %% [markdown]
# ### Deal Analysis: City Wise Analysis

# %%
df2=df['City'].value_counts()
df2.head()
# Out:
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
# Name: City, dtype: int64

# %%
df2.plot(kind='bar',figsize=(15,5))
plt.ylabel('Number of Deal')
plt.xlabel('City')
plt.title('City wise Deal',fontsize=20)
plt.show()

# %% [markdown]
# #### Top three cities Where deal i heighest
#
# 1.New York City
# 2.Los Angeles
# 3.Philadelphia

# %%
df['City'].value_counts().mean()
# Out:
# 18.821092278719398

# %% [markdown]
# #### Average mean of city is 18.82

# %% [markdown]
# ### SEGMENT Wise Analysis of Porfit, Discount, Sales

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
df_segment = df.groupby(['Segment'])[['Sales','Discount','Profit']].mean()
df_segment
# Out:
#                   Sales  Discount     Profit
# Segment
# Consumer     223.733644  0.158141  25.836873
# Corporate    233.823300  0.158228  30.456667
# Home Office  240.972041  0.147128  33.818664

# %%
df_segment.plot.pie(subplots=True,autopct='%1.1f%%',figsize=(18,20),startangle=90,label=df_segment.index)
plt.title('Segment Wise anl;ysis of Profit,Discount','Sales')
# Out:
# C:\Users\IKRAM\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1583: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-a0dc5e02bc7e> in <module>
#       1 df_segment.plot.pie(subplots=True,autopct='%1.1f%%',figsize=(18,20),startangle=90,label=df_segment.index)
# ----> 2 plt.title('Segment Wise anl;ysis of Profit,Discount','Sales')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in title(label, fontdict, loc, pad, y, **kwargs)
#    3106 @_copy_docstring_and_deprecators(Axes.set_title)
# ...

# %% [markdown]
# #### Sales: Customer Corporate Home Ofiice 32% 33.5% 34.5%

# %% [markdown]
# #### Discout: Consumer Corporate Home office 15.8% 15.8% 14.7%

# %% [markdown]
# #### Profit: Consumer Corporate Home office 28.7% 33.8% 37.5%

# %% [markdown]
# ### State Wise Analysis Sales,Discount  and Profit

# %%
df['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
df_state =df.groupby(['State'])[['Sales','Discount','Profit']].mean()
df_state.head()
# Out:
#                  Sales  Discount     Profit
# State
# Alabama     319.846557  0.000000  94.865989
# Arizona     157.508933  0.303571 -15.303235
# Arkansas    194.635500  0.000000  66.811452
# California  228.729451  0.072764  38.171608
# Colorado    176.418231  0.316484 -35.867351

# %% [markdown]
# #### 1- State Wise Profit Analysis

# %%
df_state1 = df_state.sort_values('Profit')
df_state1[['Profit']].plot(kind='bar',figsize=(15,5))
plt.title('State wise profit analysis',fontsize=20)
plt.xlabel('States')
plt.ylabel('Profit per state')
plt.show()

# %% [markdown]
# ##### Heigest profit given by State is Vermount

# %% [markdown]
# #### 2-Stae wise Sales Analysis

# %%
df_state['Sales'].plot(kind='pie',figsize=(20,20),autopct='%1.1f%%',startangle=90)
plt.title('State Wise Sales Anaysis',fontsize=20)
# Out:
# Text(0.5, 1.0, 'State Wise Sales Anaysis')

# %% [markdown]
# ##### 3-State wise analysis Discount

# %%
df_state1 = df_state.sort_values('Discount')
df_state1[['Discount']].plot(kind='bar',figsize=(15,5))
plt.title('State Wise discount',fontsize=20)
# Out:
# Text(0.5, 1.0, 'State Wise discount')

# %% [markdown]
# #### illinoiss is the top of Discount

# %% [markdown]
# ### City Wise analysis of profit

# %%
df_city = df.groupby(['City'])['Profit','Sales','Discount'].mean()
df_city
# Out:
# <ipython-input-130-00f14f815269>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_city = df.groupby(['City'])['Profit','Sales','Discount'].mean()
#                  Profit       Sales  Discount
# City
# Aberdeen       6.630000   25.500000  0.000000
# Abilene       -3.758400    1.392000  0.800000
# Akron         -8.887410  129.999333  0.357143
# Albuquerque   45.292007  158.582857  0.057143
# Alexandria    19.913644  344.973125  0.000000
# ...                 ...         ...       ...
# Woonsocket    19.669775   48.887500  0.000000
# Yonkers      184.517047  510.511067  0.066667
# York         -20.433840  163.595600  0.420000
# Yucaipa       13.208000   50.800000  0.000000
# Yuma        -116.497725  210.216250  0.450000
#
# [531 rows x 3 columns]

# %%
df_city = df_city.sort_values('Profit')
df_city.head(50)
# Out:
#                       Profit       Sales  Discount
# City
# Bethlehem        -200.619160  337.926800  0.380000
# Champaign        -182.352000  151.960000  0.600000
# Oswego           -178.709200  107.326000  0.600000
# Round Rock       -169.061614  693.436114  0.274286
# Lancaster        -157.371052  215.031826  0.315217
# Clarksville      -150.764743  316.818571  0.271429
# Medina           -149.227178  275.302444  0.433333
# Burlington       -144.915088  866.723280  0.136000
# San Antonio      -123.712715  370.229288  0.383051
# Yuma             -116.497725  210.216250  0.450000
# Pueblo           -112.621487  210.867250  0.512500
# Normal           -110.023200  366.744000  0.300000
# Rockford         -104.500709  287.838909  0.509091
# Littleton         -98.801800   72.294000  0.700000
# Tyler             -88.741720   69.441200  0.640000
# Tamarac           -87.974025  353.377500  0.450000
# Waco              -86.683900  101.017867  0.520000
# ...

# %% [markdown]
# ### Low Profit

# %%
df_city['Profit'].head(50).plot(kind='bar',figsize=(15,5))
plt.title('City Wise Low profit',fontsize=20)
# Out:
# Text(0.5, 1.0, 'City Wise Low profit')

# %% [markdown]
# ### Highest Profit

# %%
df_city['Profit'].tail(50).plot(kind='bar',figsize=(15,5))
plt.title('Gain Highest profit in term of city',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Gain Highest profit in term of city')

# %% [markdown]
# ### Quantity Wise Sales,Profit and Discount Analysis

# %%
df_quantity = df.groupby(['Quantity'])[['Profit','Sales','Discount']].mean()
df_quantity.head(50)
# Out:
#               Profit        Sales  Discount
# Quantity
# 1           8.276396    59.234632  0.152959
# 2          16.006831   120.354488  0.154858
# 3          23.667715   175.201578  0.153329
# 4          37.131310   271.764059  0.157708
# 5          40.257394   337.936339  0.157146
# 6          18.051517   362.101960  0.166556
# 7          56.579163   395.888393  0.161980
# 8          42.244342   458.210802  0.171595
# 9          68.557716   498.083683  0.147946
# 10         35.862404   422.046737  0.190702
# 11        126.275503   463.896529  0.097059
# 12         51.524609   646.452522  0.113043
# 13        235.144481  1197.710704  0.157407
# 14         93.931166   452.826138  0.151724

# %%
df_quantity.plot.pie(subplots =True,figsize=(18,20), shadow = True, autopct='%1.1f%%',label=df_category.index, startangle= 90)
plt.title('Quantity Wise Sales ,Profit and Discount analysis',fontsize=10)
plt.show()

# %% [markdown]
# ### Category Wise sales,Discount,Profit Analysis

# %%
df_category =df.groupby(['Category'])[['Sales','Discount','Profit']].mean()
df_category
# Out:
#                       Sales  Discount     Profit
# Category
# Furniture        349.834887  0.173923   8.699327
# Office Supplies  119.324101  0.157285  20.327050
# Technology       452.709276  0.132323  78.752002

# %%
df_category.plot.pie(subplots =True,figsize=(18,20),autopct='%1.1f%%',label=df_category.index, startangle= 90)
plt.show()
# Out:
# C:\Users\IKRAM\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1583: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)

# %% [markdown]
# ### Sub-Category Wise Sales, profit and  Discount

# %%
df_sub = df.groupby(['Sub-Category'])[['Profit','Sales','Discount']].mean()
df_sub
# Out:
#                   Profit        Sales  Discount
# Sub-Category
# Accessories    54.111788   215.974604  0.078452
# Appliances     38.922758   230.755710  0.166524
# Art             8.200737    34.068834  0.074874
# Binders        19.843574   133.560560  0.372292
# Bookcases     -15.230509   503.859633  0.211140
# Chairs         43.095894   532.332420  0.170178
# Copiers       817.909190  2198.941618  0.161765
# Envelopes      27.418019    64.867724  0.080315
# Fasteners       4.375660    13.936774  0.082028
# Furnishings    13.645918    95.825668  0.138349
# Labels         15.236962    34.303055  0.068681
# Machines       29.432669  1645.553313  0.306087
# Paper          24.856620    57.284092  0.074891
# Phones         50.073938   371.211534  0.154556
# Storage        25.152277   264.590553  0.074704
# Supplies       -6.258418   245.650200  0.076842
# Tables        -55.565771   648.794771  0.261285

# %%
df_sub = df_sub.sort_values('Profit')
df_sub['Profit'].plot(kind='bar',figsize=(10,5))
plt.title('Sub-Category Wise Profit',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Sub-Category Wise Profit')

# %% [markdown]
# #### Copier High Profit

# %%
df_sub['Sales'].plot.pie(figsize=(20,20),labels=df_sub.index,autopct='%1.1f%%')
plt.title('Sub-Category Wise Sales',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Sub-Category Wise Sales')

# %% [markdown]
# #### Copier the Machines have high, Sales.

# %%
df_sub['Discount'].plot.pie(startangle=90,autopct='%1.1f%%',labels=df_sub.index,figsize=(20,20))
plt.title('Sub-Category Wise Discount',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Sub-Category Wise Discount')

# %% [markdown]
# ##### Binders,Machine amd then tables have high discount

# %% [markdown]
# ### Region Wise Sales,Profit,discount

# %%
df_region= df.groupby(['Region'])[['Profit','Sales','Discount']].mean()
df_region
# Out:
#             Profit       Sales  Discount
# Region
# Central  17.092709  215.772661  0.240353
# East     32.135808  238.336110  0.145365
# South    28.857673  241.803645  0.147253
# West     33.849032  226.493233  0.109335

# %%
df_region.plot.pie(startangle=90,label=df_region.index,autopct='%1.1f%%',subplots = True,figsize=(20,200))
plt.show()
# Out:
# C:\Users\IKRAM\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1583: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)

# %% [markdown]
# #### West profit is high

# %% [markdown]
# ### Ship Mode Wise Sales, Profit, Dsiscount

# %%
df_ship = df.groupby(['Ship Mode'])[['Profit','Sales','Discount']].mean()
plt.show()

# %%
df_ship.plot.pie(subplots=True,figsize=(18,18),labels=df_ship.index,autopct='%1.1f%%',startangle= 90)
plt.show()
# Out:
# C:\Users\IKRAM\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1583: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)

# %% [markdown]
# #### 1-Profit and Discount in high in First Class  , 2-Sales is high for same dat ship

# %% [markdown]
# ### Conclusion:

# %% [raw]
# 1- Profit is high than more than that of sale but there are some areas where profit could be increased.
# 2- Profit and Discount is high in first class
# 3- Sales is high for Same day ship
# 4- Sub-Category: copier: High Proft and Sales
# 5- Sub-Category: Binders, Machines and then tables have high Discount
# 6- Category: Maximum sales and Profit Obtain in technology
# 7- State: Vermont: Highest Proftit
# 8- Category: Minimum profit  obtain in  Technology
# 9- Segment: Home-office: High Profit & sales Here is top 3 city where deals is highest. 1.New York City 2.Los Angeles 3.Philadelphia
# 10: Sales and Profit are Moderately Correlated
# 11: Discount and Profit are Negatively Correalted. Here is top 3 state where deals are highest 1.Califonia 2.New York 3.Texas
# 12: Quantity and Profit are Moderately Correlated
#
# Wyoming: Lowest Number of deal,Highest amount of  sales=Wyoming(11.8%)Lowest amount of sales = South(Dakota(0.8%)
